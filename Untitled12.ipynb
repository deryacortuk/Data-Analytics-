# %%
import  pandas as pd

# %%
url="https://raw.githubusercontent.com/tarikkranda/pi_datasets/main/country_vaccination_stats.csv"
data = pd.read_csv(url)

# %%
data
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020                 NaN
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
data['daily_vaccinations'] = data['daily_vaccinations'].fillna(0)

# %%
data
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020                 0.0
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
max_values = data.sort_values(by = ['daily_vaccinations'],ascending=False)[:3]

# %%
max_values['country']
# Out:
# 1458    United States
# 1457    United States
# 1456    United States
# Name: country, dtype: object

# %%
sum_val = data[(data["date"] == '1/6/2021')]

# %%
sum_val['daily_vaccinations'].sum()
# Out:
# 1466568.0

# %%
import pandasql as ps
url="https://raw.githubusercontent.com/tarikkranda/pi_datasets/main/country_vaccination_stats.csv"
data_sql = pd.read_csv(url)

# %%
mysql = ps.sqldf('select * from data_sql', locals())

# %%
mysql
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020                 NaN
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
query = ps.sqldf('select * from data_sql where daily_vaccinations IS NULL ', locals())

# %%
query
# Out:
#                  country        date daily_vaccinations  \
# 0              Argentina  12/29/2020               None
# 1                Austria    1/5/2021               None
# 2                Bahrain  12/23/2020               None
# 3                Belgium  12/28/2020               None
# 4                 Brazil   1/16/2021               None
# 5               Bulgaria  12/29/2020               None
# 6                 Canada  12/14/2020               None
# 7                  Chile  12/24/2020               None
# 8                  China  12/15/2020               None
# 9             Costa Rica  12/24/2020               None
# 10               Croatia  12/30/2020               None
# 11                Cyprus    1/6/2021               None
# 12               Czechia  12/27/2020               None
# 13               Denmark  12/27/2020               None
# 14               Ecuador   1/21/2021               None
# 15               England  12/20/2020               None
# ...

# %%
query1 = ps.sqldf('select COALESCE(daily_vaccinations, 0 ) from data_sql  ', locals())

# %%
query1
# Out:
#       COALESCE(daily_vaccinations, 0 )
# 0                                  0.0
# 1                              15656.0
# 2                              15656.0
# 3                              11070.0
# 4                               8776.0
# ...                                ...
# 1497                           11105.0
# 1498                           12318.0
# 1499                           15148.0
# 1500                           17371.0
# 1501                           17063.0
#
# [1502 rows x 1 columns]

# %%
query12 = ps.sqldf('SELECT country FROM data_sql ORDER BY daily_vaccinations LIMIT 1 OFFSET (SELECT COUNT(*) FROM data_sql) / 2', locals())

# %%
query12
# Out:
#   country
# 0  Greece
